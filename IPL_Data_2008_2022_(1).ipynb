# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekkosta/IPL-Data-Analysis/blob/main/IPL_Data_2008_2022_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings;
warnings.filterwarnings('ignore')

# %%
match = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
match.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
match.shape
# Out:
# (950, 20)

# %%
match['City'] = match['City'].fillna('Dubai/Sharjah')
match['City'].isnull().sum()
# Out:
# 0

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             950 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
match['City'].value_counts()
# Out:
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Dubai/Sharjah      51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: City, dtype: int64

# %%
C_City = sns.countplot(x ='City', data = match)
C_City.set_xticklabels(C_City.get_xticklabels(), rotation=90)
None

# %%
match['Team1']= match['Team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match['Team2']= match['Team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match['WinningTeam']= match['WinningTeam'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match['TossWinner']= match['TossWinner'].str.replace('Delhi Daredevils', 'Delhi Capitals')

match['Team1']= match['Team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
match['Team2']= match['Team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
match['WinningTeam']= match['WinningTeam'].str.replace('Kings XI Punjab', 'Punjab Kings')
match['TossWinner']= match['TossWinner'].str.replace('Kings XI Punjab', 'Punjab Kings')


match['Team1']= match['Team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match['Team2']= match['Team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match['WinningTeam']= match['WinningTeam'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match['TossWinner']= match['TossWinner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

# %%
match['Team1']= match['Team1'].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')
match['Team2']= match['Team2'].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')
match['WinningTeam']= match['WinningTeam'].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')
match['TossWinner']= match['TossWinner'].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')

# %%
match['Season']= match['Season'].replace('2020/21','2020')
match['Season']= match['Season'].replace('2009/10', '2010')
match['Season']= match['Season'].replace('2007/08','2008')

# %%
match['Season'].value_counts()
# Out:
# 2013    76
# 2022    74
# 2012    74
# 2011    73
# 2021    60
# 2020    60
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: Season, dtype: int64

# %%
match.nunique()
# Out:
# ID                 950
# City                34
# Date               706
# Season              15
# MatchNumber         80
# Team1               14
# Team2               14
# Venue               49
# TossWinner          14
# TossDecision         2
# SuperOver            2
# WinningTeam         14
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
toss_winner = match['TossWinner'].value_counts()
print(toss_winner)
# Out:
# Mumbai Indians                 123
# Sunrisers Hyderabad            117
# Delhi Capitals                 116
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Pune Warriors                   20
# Gujarat Lions                   15
# Rising Pune Supergiants         13
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Name: TossWinner, dtype: int64

# %%
matches_won= match[match['TossWinner']== match['WinningTeam']]['TossWinner'].value_counts()
print(matches_won)
# Out:
# Mumbai Indians                 70
# Chennai Super Kings            68
# Kolkata Knight Riders          64
# Delhi Capitals                 56
# Royal Challengers Bangalore    53
# Sunrisers Hyderabad            53
# Rajasthan Royals               49
# Punjab Kings                   40
# Gujarat Lions                  10
# Rising Pune Supergiants         8
# Gujarat Titans                  7
# Lucknow Super Giants            4
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Name: TossWinner, dtype: int64

# %%
percent_conv = (matches_won/toss_winner)*100
print(percent_conv)
# Out:
# Chennai Super Kings            62.385321
# Delhi Capitals                 48.275862
# Gujarat Lions                  66.666667
# Gujarat Titans                 70.000000
# Kochi Tuskers Kerala           50.000000
# Kolkata Knight Riders          56.140351
# Lucknow Super Giants           57.142857
# Mumbai Indians                 56.910569
# Pune Warriors                  15.000000
# Punjab Kings                   42.553191
# Rajasthan Royals               49.494949
# Rising Pune Supergiants        61.538462
# Royal Challengers Bangalore    50.476190
# Sunrisers Hyderabad            45.299145
# Name: TossWinner, dtype: float64

# %%
conv = sns.barplot(x=percent_conv.index, y=percent_conv.values)
conv.set_xticklabels(conv.get_xticklabels(), rotation=90)
plt.xlabel('Toss Winner')
plt.ylabel('Conversion Percentage')
plt.title('Conversion Percentage of Toss Winner')
plt.show()

# %%
pd.set_option('display.max_rows', None)

match.groupby(['TossWinner','City'])['TossDecision'].value_counts().to_frame("Number").sort_index()
# Out:
#                                                          Number
# TossWinner                  City           TossDecision
# Chennai Super Kings         Abu Dhabi      bat                3
#                                            field              2
#                             Ahmedabad      bat                1
#                             Bangalore      bat                1
#                                            field              3
#                             Bengaluru      field              2
#                             Cape Town      field              1
#                             Centurion      bat                2
#                             Chandigarh     bat                1
#                                            field              2
#                             Chennai        bat               22
#                                            field              8
#                             Cuttack        field              1
# ...

# %%
match['Umpire1'].value_counts()
# Out:
# AK Chaudhary             95
# HDPK Dharmasena          76
# Asad Rauf                51
# S Ravi                   48
# CB Gaffaney              47
# KN Ananthapadmanabhan    44
# M Erasmus                42
# Aleem Dar                38
# BF Bowden                36
# BR Doctrove              34
# Nitin Menon              31
# AY Dandekar              30
# BNJ Oxenford             30
# C Shamshuddin            28
# RE Koertzen              20
# S Asnani                 19
# NJ Llong                 17
# JD Cloete                16
# CK Nandan                16
# A Nand Kishore           16
# RK Illingworth           14
# BG Jerling               13
# VA Kulkarni              12
# SS Hazare                11
# S Das                    10
# MR Benson                10
# K Hariharan              10
# A Deshmukh                9
# DJ Harper                 9
# J Madanagopal             8
# GAV Baxter                7
# PG Pathak                 7
# RM Deshpande              7
# ...

# %%
match.groupby(['Team1','Team2'])['MatchNumber'].value_counts().to_frame("No.").sort_index()
# Out:
#                                                                             No.
# Team1                       Team2                       MatchNumber
# Chennai Super Kings         Delhi Capitals              2                     2
#                                                         20                    1
#                                                         26                    1
#                                                         30                    1
#                                                         34                    1
#                                                         50                    3
#                                                         55                    1
#                                                         56                    1
#                                                         59                    1
#                                                         64                    1
# ...

# %%
filtered_df = match[match['MatchNumber'].isin(['Qualifier 1', 'Qualifier 2','Eliminator'])].groupby(['Team1', 'Team2'])['MatchNumber'].value_counts().to_frame("No.")

# %%
print(filtered_df)
# Out:
#                                                                      No.
# Team1                       Team2                       MatchNumber
# Chennai Super Kings         Mumbai Indians              Qualifier 1    2
#                                                         Eliminator     1
#                             Punjab Kings                Qualifier 2    1
#                             Royal Challengers Bangalore Qualifier 2    1
# Delhi Capitals              Chennai Super Kings         Qualifier 1    1
#                                                         Qualifier 2    1
#                             Kolkata Knight Riders       Qualifier 1    1
#                                                         Qualifier 2    1
#                             Sunrisers Hyderabad         Qualifier 2    1
# Gujarat Lions               Royal Challengers Bangalore Qualifier 1    1
#                             Sunrisers Hyderabad         Qualifier 2    1
# ...

# %%
final_semifinal_counts = match[match['MatchNumber'].isin(['Qualifier 1', 'Qualifier 2','Eliminator'])]['Team1'].append(
    match[match['MatchNumber'].isin(['Qualifier 1', 'Qualifier 2','Eliminator'])]['Team2']
).value_counts()

# %%
print(final_semifinal_counts)
# Out:
# Royal Challengers Bangalore    9
# Mumbai Indians                 8
# Chennai Super Kings            8
# Delhi Capitals                 7
# Kolkata Knight Riders          7
# Rajasthan Royals               6
# Sunrisers Hyderabad            6
# Gujarat Lions                  2
# Punjab Kings                   2
# Lucknow Super Giants           1
# Gujarat Titans                 1
# Rising Pune Supergiants        1
# dtype: int64

# %%
final_counts = match[match['MatchNumber'].isin(['Final'])]['Team1'].append(
    match[match['MatchNumber'].isin(['Final'])]['Team2']
).value_counts()

print(final_counts)
# Out:
# Chennai Super Kings            9
# Mumbai Indians                 6
# Sunrisers Hyderabad            3
# Royal Challengers Bangalore    3
# Kolkata Knight Riders          3
# Rajasthan Royals               2
# Delhi Capitals                 1
# Gujarat Titans                 1
# Rising Pune Supergiants        1
# Punjab Kings                   1
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=final_semifinal_counts.index, y=final_semifinal_counts.values)
plt.title('Count of Final and Semifinal Matches for Each Team')
plt.xlabel('Team')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
filtered_df = match[match['MatchNumber'].isin(['Qualifier 1', 'Qualifier 2','Eliminator', 'Final'])]

# %%
final_semi_counts = filtered_df.groupby(['Team1', 'MatchNumber']).size().unstack().fillna(0)
print(final_semi_counts)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2
# Team1
# Chennai Super Kings                 1.0    5.0          2.0          2.0
# Delhi Capitals                      0.0    1.0          2.0          3.0
# Gujarat Lions                       0.0    0.0          1.0          1.0
# Kolkata Knight Riders               1.0    2.0          0.0          0.0
# Mumbai Indians                      0.0    3.0          2.0          2.0
# Punjab Kings                        0.0    0.0          1.0          0.0
# Rajasthan Royals                    1.0    1.0          1.0          0.0
# Royal Challengers Bangalore         4.0    2.0          1.0          2.0
# Sunrisers Hyderabad                 2.0    1.0          0.0          0.0

# %%
final_semif_counts = filtered_df.groupby(['Team2', 'MatchNumber']).size().unstack().fillna(0)
print(final_semif_counts)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2
# Team2
# Chennai Super Kings                 0.0    4.0          2.0          1.0
# Delhi Capitals                      1.0    0.0          1.0          0.0
# Gujarat Titans                      0.0    1.0          1.0          0.0
# Kolkata Knight Riders               2.0    1.0          2.0          2.0
# Lucknow Super Giants                1.0    0.0          0.0          0.0
# Mumbai Indians                      1.0    3.0          2.0          1.0
# Punjab Kings                        0.0    1.0          0.0          1.0
# Rajasthan Royals                    2.0    1.0          0.0          2.0
# Rising Pune Supergiants             0.0    1.0          1.0          0.0
# Royal Challengers Bangalore         0.0    1.0          1.0          1.0
# Sunrisers Hyderabad                 2.0    2.0          0.0          2.0

# %%
teams = final_semi_counts.index
bar_width = 0.35
index = np.arange(len(teams))

fig, ax = plt.subplots(figsize=(10, 6))
Qualifier1_bars = ax.bar(index, final_semi_counts['Qualifier 1'], bar_width, label='Qualifier 1')
Qualifier2_bars = ax.bar(index + bar_width, final_semi_counts['Qualifier 2'], bar_width, label='Qualifier 2')
Eliminator_bars = ax.bar(index + bar_width + bar_width, final_semi_counts['Eliminator'], bar_width, label='Eliminator')
Final_bars = ax.bar(index + bar_width*3, final_semi_counts['Final'], bar_width, label='Final')
ax.set_xlabel('Team')
ax.set_ylabel('Count')
ax.set_title('Count of Final and Semifinal Matches for Each Team')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(teams)
ax.legend()

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
final_semi_counts['playoff'] = final_semi_counts.sum(axis=1)
print(final_semi_counts)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2  \
# Team1
# Chennai Super Kings                 1.0    5.0          2.0          2.0
# Delhi Capitals                      0.0    1.0          2.0          3.0
# Gujarat Lions                       0.0    0.0          1.0          1.0
# Kolkata Knight Riders               1.0    2.0          0.0          0.0
# Mumbai Indians                      0.0    3.0          2.0          2.0
# Punjab Kings                        0.0    0.0          1.0          0.0
# Rajasthan Royals                    1.0    1.0          1.0          0.0
# Royal Challengers Bangalore         4.0    2.0          1.0          2.0
# Sunrisers Hyderabad                 2.0    1.0          0.0          0.0
#
# MatchNumber                  playoff
# Team1
# Chennai Super Kings             10.0
# Delhi Capitals                   6.0
# Gujarat Lions                    2.0
# Kolkata Knight Riders            3.0
# ...

# %%
final_semif_counts['playoff'] = final_semif_counts.sum(axis=1)
print(final_semif_counts)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2  \
# Team2
# Chennai Super Kings                 0.0    4.0          2.0          1.0
# Delhi Capitals                      1.0    0.0          1.0          0.0
# Gujarat Titans                      0.0    1.0          1.0          0.0
# Kolkata Knight Riders               2.0    1.0          2.0          2.0
# Lucknow Super Giants                1.0    0.0          0.0          0.0
# Mumbai Indians                      1.0    3.0          2.0          1.0
# Punjab Kings                        0.0    1.0          0.0          1.0
# Rajasthan Royals                    2.0    1.0          0.0          2.0
# Rising Pune Supergiants             0.0    1.0          1.0          0.0
# Royal Challengers Bangalore         0.0    1.0          1.0          1.0
# Sunrisers Hyderabad                 2.0    2.0          0.0          2.0
#
# MatchNumber                  playoff
# Team2
# Chennai Super Kings              7.0
# ...

# %%
result = final_semif_counts.add(final_semi_counts,fill_value=0)
print(result)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2  \
# Chennai Super Kings                 1.0    9.0          4.0          3.0
# Delhi Capitals                      1.0    1.0          3.0          3.0
# Gujarat Lions                       0.0    0.0          1.0          1.0
# Gujarat Titans                      0.0    1.0          1.0          0.0
# Kolkata Knight Riders               3.0    3.0          2.0          2.0
# Lucknow Super Giants                1.0    0.0          0.0          0.0
# Mumbai Indians                      1.0    6.0          4.0          3.0
# Punjab Kings                        0.0    1.0          1.0          1.0
# Rajasthan Royals                    3.0    2.0          1.0          2.0
# Rising Pune Supergiants             0.0    1.0          1.0          0.0
# Royal Challengers Bangalore         4.0    3.0          2.0          3.0
# Sunrisers Hyderabad                 4.0    3.0          0.0          2.0
#
# ...

# %%
result.columns
# Out:
# Index(['Eliminator', 'Final', 'Qualifier 1', 'Qualifier 2', 'playoff'], dtype='object', name='MatchNumber')

# %%
result.shape
# Out:
# (12, 5)

# %%
print(result)
# Out:
# MatchNumber                  Eliminator  Final  Qualifier 1  Qualifier 2  \
# Chennai Super Kings                 1.0    9.0          4.0          3.0
# Delhi Capitals                      1.0    1.0          3.0          3.0
# Gujarat Lions                       0.0    0.0          1.0          1.0
# Gujarat Titans                      0.0    1.0          1.0          0.0
# Kolkata Knight Riders               3.0    3.0          2.0          2.0
# Lucknow Super Giants                1.0    0.0          0.0          0.0
# Mumbai Indians                      1.0    6.0          4.0          3.0
# Punjab Kings                        0.0    1.0          1.0          1.0
# Rajasthan Royals                    3.0    2.0          1.0          2.0
# Rising Pune Supergiants             0.0    1.0          1.0          0.0
# Royal Challengers Bangalore         4.0    3.0          2.0          3.0
# Sunrisers Hyderabad                 4.0    3.0          0.0          2.0
#
# ...
